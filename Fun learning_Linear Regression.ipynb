# %% [markdown]
# # Linear Regression

# %%
from IPython.display import Image
Image("img_neural/lr1.png")

# %%
Image("img_neural/lr2.png")

# %%
from IPython.display import HTML

HTML("""
<video width="920" height="440" controls>
  <source src="img_neural/1.webm" type="video/webm">
</video>
""")


# we have to find the min avg distance of line from all the points with the help of model function(in this case wags(x) func)
# Out:
# <video width="920" height="440" controls>
#   <source src="img_neural/1.webm" type="video/webm">
# </video>

# %%
Image("img_neural/lr3.png")

# %%
Image("img_neural/lr4.png")

# %%
Image("img_neural/lr5.png")
